# %% [markdown]
# # Statistics Advance Part 1
# 1. What is a random variable in probability theory?
#   - A random variable in probability theory is a function that assigns numerical values to the outcomes of a random experiment.
# 2. What are the types of random variables?
#     - Discrete Random Variable – Takes a countable number of distinct values (e.g., number of heads in 3 coin tosses).
#     - Continuous Random Variable – Takes an infinite number of values within a range (e.g., height of people, time taken to finish a race).
# 3. What is the difference between discrete and continuous distributions?
#   - Discrete Distribution
#     - Deals with countable values
#     - Finite or infinite but distinct values (e.g., 0, 1, 2…)
#     - Probability Mass Function (PMF)
#     - P(X = x) gives the probability of an exact value
#
#   - Continuous Distribution
#     - Deals with uncountable values (range)
#     - Any value within an interval (e.g., 1.2, 2.5, 3.8…)
#     - Probability Density Function (PDF)
#     - P(a ≤ X ≤ b) is found using integration (area under curve)
# 4. What are probability distribution functions (PDF)?
#   - A Probability Distribution Function (PDF) describes how probabilities are distributed over possible values of a random variable.
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#   - Probability Distribution Function (PDF/PMF)
#     - Describes the probability of a specific value (PMF for discrete, PDF for continuous).
#     - For discrete: Probability values (0 ≤ P(X = x) ≤ 1). For continuous: Probability density, not direct probability.
#     - Gives probability at an exact value.
#     - If X is a height following a normal distribution, 𝑓(𝑥)f(x) gives density at X
#
#   - Cumulative Distribution Function (CDF)
#     - Describes the probability that a random variable X is less than or equal to a value (P(X ≤ x)).
#     - Always increases from 0 to 1.
#     - Gives cumulative probability up to a point.
#     - F(170)=P(X≤170), found by integrating PDF from −∞  to 170.
# 6. What is a discrete uniform distribution?
#   - A Discrete Uniform Distribution is a probability distribution where all possible values have equal probability.
# 7. What are the key properties of a Bernoulli distribution?
#   - Probability Mass Function (PMF)
#         P(X=x)=p x (1−p) 1− ,x∈{0,1}
#   -  Mean (Expected Value)   E(X)=p
#   - Variance  𝑉𝑎𝑟(𝑋)=𝑝(1−𝑝)Var(X)=p(1−p)
#   - Standard Deviation  𝜎=𝑝(1−𝑝)σ= p(1−p)
#   - Special Case of Binomial Distribution
#       - A Bernoulli distribution is a binomial distribution with n = 1 (single trial).
#
# 8. What is the binomial distribution, and how is it used in probability?
#   - A binomial distribution models the probability of getting a certain number of successes in n independent trials of a Bernoulli experiment (each trial has two possible outcomes: success or failure).
# 9. What is the Poisson distribution and where is it applied?
#   - The Poisson distribution models the probability of a certain number of events occurring in a fixed interval of time or space, given the events happen at a constant average rate and independently of each other.
# 10. What is a continuous uniform distribution?
#   - A Continuous Uniform Distribution is a probability distribution where all values within a given interval are equally likely.
# 11. What are the characteristics of a normal distribution?
#   - Bell-Shaped Curve : Symmetrical around the mean μ.
#   - Mean = Median = Mode : The peak is at the mean, and it is also the median and mode.
#   - Infinite Range : Values range from −∞ to ∞ , but extreme values are rare.
# 12. What is the standard normal distribution, and why is it important?
#   - The Standard Normal Distribution is a special case of the normal distribution where:
#       - Mean (μ) = 0
#       - Standard deviation (σ) = 1
#       - It follows the same bell-shaped curve as a normal distribution but is standardized.
#   - Why Is It Important?
#       - Simplifies Probability Calculations
#       - Universal Reference for Normal Distributions
#       - Basis for Hypothesis Testing & Confidence Intervals
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#   - The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the original population distribution.
#   - Why Is CLT Critical in Statistics?
#      - Enables Inferential Statistics
#           - Allows us to make predictions about a population using a sample.
#      - Foundation for Hypothesis Testing & Confidence Intervals
#           - Used in Z-tests, t-tests, and confidence interval estimation.
#      - Real-World Applications
#           - Polling: Estimating population preferences from survey samples.
#           - Quality Control: Checking manufacturing defects from random samples.
#           - Finance: Modeling stock returns using sample data.
# 14. How does the Central Limit Theorem relate to the normal distribution?
#   - The Central Limit Theorem (CLT) explains why the normal distribution appears in many real-world scenarios, even when the original data is not normally distributed. It establishes a direct link between sampling distributions and the normal distribution.
# 15. What is the application of Z statistics in hypothesis testing?
#   - Z-Statistics (or Z-test) is used in hypothesis testing when:
#       - The sample size is large (𝑛≥30), or
#       - The population standard deviation (σ) is known.
# 16. How do you calculate a Z-score, and what does it represent?
#   - A Z-score (also called the standard score) measures how many standard deviations a data point is from the mean. It tells us whether a value is above or below the average and by how much.
#   - Formula for Z-Score    Z= X−μ/σ
# 17. What are point estimates and interval estimates in statistics?
#     -  In statistics, estimation is used to infer population parameters from sample data. It can be done using point estimates and interval estimates.
#
# 18. What is the significance of confidence intervals in statistical analysis?
#     - A Confidence Interval (CI) is a range of values that estimates an unknown population parameter with a certain level of confidence (e.g., 95%). It helps assess the accuracy and reliability of an estimate.
# 19. What is the relationship between a Z-score and a confidence interval?
#   - A Z-score is used to determine the confidence interval (CI) in normal distributions. It helps establish how far sample estimates can deviate from the population mean with a given confidence level.
# 20. How are Z-scores used to compare different distributions?
#   - A Z-score standardizes values from different distributions, making them comparable by converting them into a common scale based on standard deviations.
# 21. What are the assumptions for applying the Central Limit Theorem?
#   - The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean approaches a normal distribution, regardless of the population distribution, as long as the sample size is sufficiently large.
#
# 22. What is the concept of expected value in a probability distribution?
#   - The expected value (mean) of a probability distribution represents the long-run average outcome of a random variable.
# 23. How does a probability distribution relate to the expected outcome of a random variable?
#   - A probability distribution describes the possible values a random variable can take and their associated probabilities. The expected outcome (expected value) is the weighted average of these values, where each value is weighted by its probability.

# %%
#1. Write a Python program to generate a random variable and display its value.
import random
random_variable = random.randint(1, 10)
print("Random Variable:", random_variable)
# Out:
# Random Variable: 4

# %%
#2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint
low, high = 1, 6
x = np.arange(low, high + 1)
pmf_values = randint.pmf(x, low, high + 1)
plt.bar(x, pmf_values, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Values of X")
plt.ylabel("Probability")
plt.title("Discrete Uniform Distribution PMF (Rolling a Die)")
plt.xticks(x)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
#.3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.
def bernoulli_pdf(x, p):
    """
    Compute the Probability Distribution Function (PDF) of a Bernoulli distribution.

    Parameters:
    x (int): The random variable (0 or 1)
    p (float): The probability of success (0 ≤ p ≤ 1)

    Returns:
    float: The probability mass function (PMF) value for the given x
    """
    if x not in [0, 1]:
        return 0
    return p**x * (1 - p)**(1 - x)
p = 0.6
print("P(X=0):", bernoulli_pdf(0, p))
print("P(X=1):", bernoulli_pdf(1, p))
# Out:
# P(X=0): 0.4
# P(X=1): 0.6

# %%
#4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n = 10
p = 0.5

samples = np.random.binomial(n, p, 1000)

plt.hist(samples, bins=np.arange(12) - 0.5, density=True, alpha=0.7, color='blue', edgecolor='black', label="Simulated Data")

x = np.arange(0, n + 1)
pmf_values = binom.pmf(x, n, p)
plt.plot(x, pmf_values, 'ro-', label="True PMF")

plt.xlabel("Number of Successes (X)")
plt.ylabel("Probability")
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xticks(range(n + 1))
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
#5.Create a Poisson distribution and visualize it using Python
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# %%
#6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

lambda_val = 5


x = np.arange(0, 15)
pmf_values = poisson.pmf(x, lambda_val)


plt.bar(x, pmf_values, color='blue', alpha=0.7, edgecolor='black', label="Poisson PMF")
plt.xlabel("Number of Events (X)")
plt.ylabel("Probability")
plt.title(f"Poisson Distribution (λ={lambda_val})")
plt.xticks(x)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.legend()

plt.show()

# %%
#7.Generate a continuous uniform distribution using NumPy and visualize it
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

a, b = 0, 10
samples = np.random.uniform(a, b, 1000)

plt.hist(samples, bins=30, density=True, alpha=0.7, color='blue', edgecolor='black', label="Simulated Data")

x = np.linspace(a, b, 100)
pdf_values = uniform.pdf(x, a, b - a)
plt.plot(x, pdf_values, 'r-', label="True PDF")

plt.xlabel("Value of X")
plt.ylabel("Probability Density")
plt.title("Continuous Uniform Distribution (0 to 10)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
#8.Simulate data from a normal distribution and plot its histogram
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu = 0
sigma = 1

samples = np.random.normal(mu, sigma, 1000)

plt.hist(samples, bins=30, density=True, alpha=0.7, color='blue', edgecolor='black', label="Simulated Data")

x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
pdf_values = norm.pdf(x, mu, sigma)
plt.plot(x, pdf_values, 'r-', label="True PDF")

plt.xlabel("Value of X")
plt.ylabel("Probability Density")
plt.title("Normal Distribution (μ=0, σ=1)")
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()

# %%
#9.Write a Python function to calculate Z-scores from a dataset and plot them
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_z_scores(data):
    mean = np.mean(data)
    std_dev = np.std(data, ddof=1)
    return (data - mean) / std_dev

data = np.random.normal(50, 15, 100)
z_scores = calculate_z_scores(data)

plt.figure(figsize=(8, 5))
sns.histplot(z_scores, bins=30, kde=True, color='blue')
plt.axvline(0, color='red', linestyle='dashed', label="Mean (Z=0)")
plt.xlabel("Z-score")
plt.ylabel("Frequency")
plt.title("Z-score Distribution")
plt.legend()
plt.grid()
plt.show()

# %%
#10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

population = np.random.uniform(0, 100, 10000)
sample_size = 30
num_samples = 1000
sample_means = [np.mean(np.random.choice(population, sample_size, replace=True)) for _ in range(num_samples)]

plt.figure(figsize=(8, 5))
sns.histplot(sample_means, bins=30, kde=True, color='blue')
plt.axvline(np.mean(population), color='red', linestyle='dashed', label="Population Mean")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.title("Central Limit Theorem Demonstration")
plt.legend()
plt.grid()
plt.show()

# %%
#11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

population = np.random.normal(50, 15, 10000)
sample_size = 30
num_samples = 1000
sample_means = [np.mean(np.random.choice(population, sample_size, replace=True)) for _ in range(num_samples)]

plt.figure(figsize=(8, 5))
sns.histplot(sample_means, bins=30, kde=True, color='blue')
plt.axvline(np.mean(population), color='red', linestyle='dashed', label="Population Mean")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.title("Central Limit Theorem Verification")
plt.legend()
plt.grid()
plt.show()

# %%
#12.Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def standard_normal_distribution():
    x = np.linspace(-4, 4, 100)
    pdf_values = norm.pdf(x, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf_values, 'b-', label="Standard Normal PDF")
    plt.axvline(0, color='red', linestyle='dashed', label="Mean (μ=0)")
    plt.xlabel("Z-score")
    plt.ylabel("Probability Density")
    plt.title("Standard Normal Distribution (μ=0, σ=1)")
    plt.legend()
    plt.grid()
    plt.show()

standard_normal_distribution()

# %%
#13.Generate random variables and calculate their corresponding probabilities using the binomial distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n, p = 10, 0.5
x = np.arange(0, n + 1)
probabilities = binom.pmf(x, n, p)

plt.bar(x, probabilities, color='blue', edgecolor='black', alpha=0.7, label="Binomial PMF")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.title(f"Binomial Distribution (n={n}, p={p})")
plt.xticks(x)
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
#14.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data_point, mean, std_dev):
    return (data_point - mean) / std_dev

data = np.random.normal(50, 15, 1000)
mean, std_dev = np.mean(data), np.std(data, ddof=1)
data_point = 60
z_score = calculate_z_score(data_point, mean, std_dev)

x = np.linspace(-4, 4, 100)
pdf_values = norm.pdf(x, 0, 1)

plt.figure(figsize=(8, 5))
plt.plot(x, pdf_values, 'b-', label="Standard Normal PDF")
plt.axvline(z_score, color='red', linestyle='dashed', label=f"Z-score={z_score:.2f}")
plt.xlabel("Z-score")
plt.ylabel("Probability Density")
plt.title("Comparison with Standard Normal Distribution")
plt.legend()
plt.grid()
plt.show()

# %%
#15.Implement hypothesis testing using Z-statistics for a sample dataset
import numpy as np
import scipy.stats as stats

def z_test(sample, population_mean, population_std, alpha=0.05):
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    standard_error = population_std / np.sqrt(sample_size)

    z_score = (sample_mean - population_mean) / standard_error
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    reject_null = p_value < alpha
    return z_score, p_value, reject_null

sample_data = np.random.normal(52, 10, 30)
population_mean = 50
population_std = 10
alpha = 0.05

z_score, p_value, reject_null = z_test(sample_data, population_mean, population_std, alpha)

print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.4f}")
print("Reject Null Hypothesis" if reject_null else "Fail to Reject Null Hypothesis")
# Out:
# Z-score: -0.17
# P-value: 0.8611
# Fail to Reject Null Hypothesis

# %%
#16.Create a confidence interval for a dataset using Python and interpret the result
import numpy as np
import scipy.stats as stats

def confidence_interval(data, confidence=0.95):
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    sample_size = len(data)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size - 1) * (sample_std / np.sqrt(sample_size))
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

data = np.random.normal(50, 10, 30)
conf_int = confidence_interval(data, 0.95)

print(f"95% Confidence Interval: ({conf_int[0]:.2f}, {conf_int[1]:.2f})")
# Out:
# 95% Confidence Interval: (49.54, 56.39)

# %%
  #17.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
import numpy as np
import scipy.stats as stats

def confidence_interval(data, confidence=0.95):
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)
    sample_size = len(data)

    margin_of_error = stats.t.ppf((1 + confidence) / 2, df=sample_size - 1) * (sample_std / np.sqrt(sample_size))
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound, sample_mean

data = np.random.normal(50, 10, 30)
lower, upper, mean = confidence_interval(data, 0.95)

print(f"Sample Mean: {mean:.2f}")
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")

if lower <= 50 <= upper:
    print("The population mean of 50 is within the confidence interval.")
else:
    print("The population mean of 50 is NOT within the confidence interval.")
# Out:
# Sample Mean: 49.33
# 95% Confidence Interval: (45.73, 52.92)
# The population mean of 50 is within the confidence interval.

# %%
#18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mean, std_dev = 50, 10
x = np.linspace(mean - 4 * std_dev, mean + 4 * std_dev, 100)
pdf_values = norm.pdf(x, mean, std_dev)

plt.figure(figsize=(8, 5))
plt.plot(x, pdf_values, 'b-', label="Normal Distribution PDF")
plt.axvline(mean, color='red', linestyle='dashed', label="Mean (μ)")
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.title("Normal Distribution PDF (μ=50, σ=10)")
plt.legend()
plt.grid()
plt.show()

# %%
#19.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

lambda_value = 5
x = np.arange(0, 15)
cdf_values = poisson.cdf(x, lambda_value)

plt.figure(figsize=(8, 5))
plt.step(x, cdf_values, where="mid", color="blue", label="Poisson CDF (λ=5)")
plt.xlabel("Number of Events (k)")
plt.ylabel("Cumulative Probability")
plt.title("Poisson Distribution CDF (λ=5)")
plt.legend()
plt.grid()
plt.show()

probability_k_less_than_7 = poisson.cdf(7, lambda_value)
print(f"P(X ≤ 7) = {probability_k_less_than_7:.4f}")
# Out:
# P(X ≤ 7) = 0.8666

# %%
#20.Simulate a random variable using a continuous uniform distribution and calculate its expected value
import numpy as np

a, b = 10, 20
random_variable = np.random.uniform(a, b, 1000)
expected_value = (a + b) / 2

print(f"Expected Value: {expected_value:.2f}")
# Out:
# Expected Value: 15.00

# %%
  #21.  Write a Python program to compare the standard deviations of two datasets and visualize the difference
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(50, 20, 1000)

std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

plt.figure(figsize=(8, 5))
sns.kdeplot(data1, label=f"Dataset 1 (σ={std1:.2f})", color="blue", shade=True)
sns.kdeplot(data2, label=f"Dataset 2 (σ={std2:.2f})", color="red", shade=True)
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Comparison of Standard Deviations")
plt.legend()
plt.grid()
plt.show()

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")
# Out:
# <ipython-input-53-14f13559b3d0>:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data1, label=f"Dataset 1 (σ={std1:.2f})", color="blue", shade=True)
# <ipython-input-53-14f13559b3d0>:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data2, label=f"Dataset 2 (σ={std2:.2f})", color="red", shade=True)
# Standard Deviation of Dataset 1: 9.71
# Standard Deviation of Dataset 2: 20.43

# %%
#22.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

# %%
#23.Implement Z-score normalization on a dataset and visualize its transformation.
import numpy as np

data = np.random.normal(50, 15, 1000)

data_range = np.max(data) - np.min(data)
q1, q3 = np.percentile(data, [25, 75])
iqr = q3 - q1

print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Range: 104.23
# Interquartile Range (IQR): 19.28

# %%
  #24. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.
import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(data):
    skewness = skew(data)
    kurt = kurtosis(data)
    return skewness, kurt

data = np.random.normal(50, 15, 1000)
skewness, kurt = calculate_skewness_kurtosis(data)

print(f"Skewness: {skewness:.2f}")
print(f"Kurtosis: {kurt:.2f}")
# Out:
# Skewness: -0.04
# Kurtosis: -0.05
